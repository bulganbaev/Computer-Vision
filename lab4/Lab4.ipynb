# %% [markdown]
# # Pattern match
# ### Task: Сделайте self фото на некотором расстоянии от камеры с поднятой рукой. Сделайте crop вашей руки - это ваш шаблон. Исходное изображение - это матрица в которой вы будете искать шаблон.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as img
from PIL import Image
from skimage import data
from skimage.feature import match_template

image = cv2.imread('./1.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image = gray_image
coin = image[300:600, 700:900]



result = match_template(image, coin)
ij = np.unravel_index(np.argmax(result), result.shape)
x, y = ij[::-1]

fig = plt.figure(figsize=(8, 6))
ax1 = plt.subplot(1, 3, 1)
ax2 = plt.subplot(1, 3, 2)
ax3 = plt.subplot(1, 3, 3)

ax1.imshow(coin, cmap=plt.cm.gray)
ax1.set_axis_off()
ax1.set_title('template')

ax2.imshow(gray_image, cmap=plt.cm.gray)
ax2.set_axis_off()
ax2.set_title('image')
# highlight matched region
hcoin, wcoin = coin.shape
rect = plt.Rectangle((x, y), wcoin, hcoin, edgecolor='r', facecolor='none')
ax2.add_patch(rect)

ax3.imshow(result)
ax3.set_axis_off()
ax3.set_title('`match_template`\nresult')
# highlight matched region
ax3.autoscale(False)
ax3.plot(x, y, 'o', markeredgecolor='r', markerfacecolor='none', markersize=10)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np

from skimage import data
from skimage.feature import match_template

image = img.imread('./1.jpg')
arm = image[300:600, 700:900]

result = match_template(image, arm)
ij = np.unravel_index(np.argmax(result), result.shape)
z,x, y = ij[::-1]
print(ij)

fig = plt.figure(figsize=(8, 3))
ax1 = plt.subplot(1, 3, 1)
ax2 = plt.subplot(1, 3, 2, adjustable='box-forced')
ax3 = plt.subplot(1, 3, 3, sharex=ax2, sharey=ax2, adjustable='box-forced')

ax1.imshow(arm, cmap=plt.cm.gray)
ax1.set_axis_off()
ax1.set_title('template')

ax2.imshow(image, cmap=plt.cm.gray)
ax2.set_axis_off()
ax2.set_title('image')
# highlight matched region
hcoin, wcoin, z = arm.shape
print(arm.shape)
rect = plt.Rectangle((x, y), wcoin, hcoin, edgecolor='r', facecolor='none')
ax2.add_patch(rect)

ax3.imshow(result)
ax3.set_axis_off()
ax3.set_title('`match_template`\nresult')
# highlight matched region
ax3.autoscale(False)
ax3.plot(x, y, 'o', markeredgecolor='r', markerfacecolor='none', markersize=10)


plt.show()
# Out:
# (300, 700, 0)
# (300, 200, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-290a210bdaee> in <module>()
#      32 ax2.add_patch(rect)
#      33
# ---> 34 ax3.imshow(result)
#      35 ax3.set_axis_off()
#      36 ax3.set_title('`match_template`\nresult')
#
# C:\Users\bulga\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Users\bulga\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5122                               resample=resample, **kwargs)
#    5123
# -> 5124         im.set_data(X)
#    5125         im.set_alpha(alpha)
#    5126         if im.get_clip_path() is None:
#
# C:\Users\bulga\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     598         if (self._A.ndim not in (2, 3) or
#     599                 (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 600             raise TypeError("Invalid dimensions for image data")
#     601
#     602         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %%
import matplotlib.image as img
import numpy as np
# Out:
# (300, 200, 3)
